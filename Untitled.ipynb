# %%
#libraries
import dash
import dash_labs as dl
import dash_bootstrap_components as dbc
import warnings
warnings.filterwarnings("ignore")

import dash
from dash.dependencies import Input, Output
import dash_core_components as dcc
import dash_html_components as html
import dash_bootstrap_components as dbc




# Data
import pandas as pd


# Visualisation
import seaborn as sns
import plotly.express as px
#from callbacks import register_callbacks


request_path_prefix = None


df = pd.read_csv("data.csv")


# Dash instance declaration
app = dash.Dash(__name__, plugins=[dl.plugins.pages], requests_pathname_prefix=request_path_prefix, external_stylesheets=[dbc.themes.FLATLY],)



#Top menu, items get from all pages registered with plugin.pages
navbar = dbc.NavbarSimple([

    dbc.NavItem(dbc.NavLink( "Inicio", href=request_path_prefix)),
    dbc.DropdownMenu(
        [

            dbc.DropdownMenuItem(page["name"], href=request_path_prefix or page["path"])
            for page in dash.page_registry.values()
            if page["module"] != "pages.not_found_404"
        ],
        nav=True,
        label="Menú",
    ),
    dbc.NavItem(dbc.NavLink("Nosotros", href=request_path_prefix and "/nosotros")),
    ],
    brand="Anaálisis de la prueba saber 11 año 2019",
    color="primary",
    dark=True,
    className="mb-2",
)

#Main layout
app.layout = dbc.Container(
    [
        navbar,
        dl.plugins.page_container,
    ],
    className="dbc",
    fluid=True,
)

# Call to external function to register all callbacks
#register_callbacks(app)


# This call will be used with Gunicorn server
server = app.server

# Testing server, don't use in production, host
if __name__ == "__main__":
    app.run_server(debug=False)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [1], in <cell line: 34>()
#      30 df = pd.read_csv("data.csv")
#      33 # Dash instance declaration
# ---> 34 app = dash.Dash(__name__, plugins=[dl.plugins.pages], requests_pathname_prefix=request_path_prefix, external_stylesheets=[dbc.themes.FLATLY],)
#      38 #Top menu, items get from all pages registered with plugin.pages
#      39 navbar = dbc.NavbarSimple([
#      40
#      41     dbc.NavItem(dbc.NavLink( "Inicio", href=request_path_prefix)),
#    (...)
#      57     className="mb-2",
#      58 )
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/dash/dash.py:498, in Dash.__init__(self, name, server, assets_folder, pages_folder, use_pages, assets_url_path, assets_ignore, assets_external_path, eager_loading, include_assets_files, url_base_pathname, requests_pathname_prefix, routes_pathname_prefix, serve_locally, compress, meta_tags, index_string, external_scripts, external_stylesheets, suppress_callback_exceptions, prevent_initial_callbacks, show_undo_redo, extra_hot_reload_paths, plugins, title, update_title, long_callback_manager, background_callback_manager, **obsolete)
#     496 if isinstance(plugins, patch_collections_abc("Iterable")):
#     497     for plugin in plugins:
# --> 498         plugin.plug(self)
#     500 if self.server is not None:
#     501     self.init_app()
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/dash_labs/plugins/pages.py:327, in plug(app)
#     325 pages_folder = os.path.join(flask.helpers.get_root_path(app.config.name), "pages")
#     326 if os.path.exists(pages_folder):
# --> 327     _import_layouts_from_pages(pages_folder)
#     328 else:
#     329     warnings.warn("A folder called `pages` does not exist.", stacklevel=2)
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/dash_labs/plugins/pages.py:301, in _import_layouts_from_pages(pages_folder)
#     299 _, _, page_filename = page_filename.partition("pages/")
#     300 page_filename = page_filename.replace(".py", "").replace("/", ".")
# --> 301 page_module = importlib.import_module(f"pages.{page_filename}")
#     303 if f"pages.{page_filename}" in dash.page_registry:
#     304     dash.page_registry[f"pages.{page_filename}"]["layout"] = getattr(
#     305         page_module, "layout"
#     306     )
#
# File ~/opt/anaconda3/lib/python3.9/importlib/__init__.py:127, in import_module(name, package)
#     125             break
#     126         level += 1
# --> 127 return _bootstrap._gcd_import(name[level:], package, level)
#
# File <frozen importlib._bootstrap>:1030, in _gcd_import(name, package, level)
#
# File <frozen importlib._bootstrap>:1007, in _find_and_load(name, import_)
#
# File <frozen importlib._bootstrap>:986, in _find_and_load_unlocked(name, import_)
#
# File <frozen importlib._bootstrap>:680, in _load_unlocked(spec)
#
# File <frozen importlib._bootstrap_external>:850, in exec_module(self, module)
#
# File <frozen importlib._bootstrap>:228, in _call_with_frames_removed(f, *args, **kwds)
#
# File ~/PycharmProjects/Project/pages/basicpage.py:48, in <module>
#      21 # specific layout for this page
#      23 layout = dbc.Container(
#      24     [
#      25         dbc.Row([
#    (...)
#      45         ])
#      46 ])
# ---> 48 @app.callback(
#      49     Output('the_graph', 'figure'),
#      50     Input('My_dropdown', 'value')
#      51 )
#      52 def update_graph(My_dropdown):
#      53     df14 = df[[My_dropdown, 'PUNT_GLOBAL']].groupby([My_dropdown]).mean()
#      54     df14 = df14.reset_index()
#
# NameError: name 'app' is not defined
